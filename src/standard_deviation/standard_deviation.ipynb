# %% [markdown]
# ### Standard Deviation
#
# Standard deviation (ST) = Variance (ML)
#
# [[error bar function example](https://matplotlib.org/stable/gallery/statistics/errorbar.html)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# example data
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

fig, ax = plt.subplots()
ax.errorbar(x, y, xerr=0.1, yerr=0.3,marker = 'o')
plt.show()

# %% [markdown]
# ### Different ways of specifying error bars
# [ref](https://matplotlib.org/stable/gallery/statistics/errorbar_features.html)
#
# If the raw x and y data have length N, there are two options:
#
# *Array of shape (N,):*
#
#     Error varies for each point, but the error values are symmetric (i.e. the lower and upper values are equal).
#
# *Array of shape (2, N):*
#
#     Error varies for each point, and the lower and upper limits (in that order) are different (asymmetric case)
#
# In addition, this example demonstrates how to use log scale with error bars.
